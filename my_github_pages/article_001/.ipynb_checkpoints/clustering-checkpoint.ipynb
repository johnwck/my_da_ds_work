# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#    hour_of_day   method    duration
# 0           13  control  117.969829
# 1           15  control  106.665437
# 2            9      new   97.036785
# 3           13  control  107.906207
# 4            3      new   70.665614

# %% [markdown]
# # First Result

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
figure, axis = plt.subplots(1, 2, figsize=(14,4), width_ratios=[1,2])

sns.boxplot(x=df['method'], y=df['duration'], ax=axis[0])
axis[0].set_title('duration vs method')
axis[0].set_ylim(ymin=0, ymax=150)

sns.histplot(x=df['duration'], hue=df['method'], element='poly', bins=20, ax=axis[1])
axis[1].set_title('duration by method')
axis[1].set_xlim(xmin=20, xmax=140);

# %%
from statsmodels.formula.api import ols

# %%
lr = ols(formula='duration ~ hour_of_day + method + hour_of_day*method', data=df)

# %%
lr_result = lr.fit()

# %%
print(lr_result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               duration   R-squared:                       0.217
# Model:                            OLS   Adj. R-squared:                  0.207
# Method:                 Least Squares   F-statistic:                     21.86
# Date:                Sun, 29 Oct 2023   Prob (F-statistic):           1.58e-12
# Time:                        11:58:41   Log-Likelihood:                -978.66
# No. Observations:                 240   AIC:                             1965.
# Df Residuals:                     236   BIC:                             1979.
# Df Model:                           3
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                   101.7727      2.582     39.416      0.000      96.686     106.859
# method[T.new]               -22.2118      3.802     -5.843      0.000     -29.701     -14.722
# hour_of_day                   0.2261      0.201      1.126      0.261      -0.170       0.622
# hour_of_day:method[T.new]     1.1521      0.287      4.020      0.000       0.588       1.717
# ==============================================================================
# Omnibus:                        0.407   Durbin-Watson:                   2.072
# Prob(Omnibus):                  0.816   Jarque-Bera (JB):                0.547
# Skew:                          -0.060   Prob(JB):                        0.761
# Kurtosis:                       2.799   Cond. No.                         71.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Hierarchical Clustering - Second Result

# %%
from sklearn import preprocessing

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
df['method'] = label_encoder.fit_transform(df['method'])

# %%
df.head()
# Out:
#    hour_of_day  method    duration
# 0           13       0  117.969829
# 1           15       0  106.665437
# 2            9       1   97.036785
# 3           13       0  107.906207
# 4            3       1   70.665614

# %%
from scipy.cluster.hierarchy import dendrogram, linkage, cut_tree

# %%
linkage_data = linkage(df, method='ward', metric='euclidean')

# %%
figure, axis = plt.subplots(figsize=(9,4))
dendrogram(linkage_data)
plt.show();

# %%
cluster_labels = cut_tree(linkage_data, n_clusters=2).reshape(-1,1)

# %%
df['cluster'] = pd.DataFrame(cluster_labels)

# %%
df.head()
# Out:
#    hour_of_day  method    duration  cluster
# 0           13       0  117.969829        0
# 1           15       0  106.665437        0
# 2            9       1   97.036785        1
# 3           13       0  107.906207        0
# 4            3       1   70.665614        1

# %%
df1 = pd.pivot_table(df, index=['cluster','method'], values='hour_of_day', aggfunc='count').reset_index().rename_axis(None, axis=1).rename(columns={'hour_of_day':'count'})
df1
# Out:
#    cluster  method  count
# 0        0       0     63
# 1        0       1     43
# 2        1       0     55
# 3        1       1     79

# %%
figure, axis = plt.subplots(1, 3, figsize=(14,4), width_ratios=[1,1,1.5])

sns.boxplot(x=df['cluster'], y=df['hour_of_day'], ax=axis[0])
axis[0].set_title('hour_of_day vs cluster')
axis[0].set_ylim(0, 25)

sns.boxplot(x=df['cluster'], y=df['duration'], ax=axis[1])
axis[1].set_title('duration vs cluster')
axis[1].set_ylim(0, 160)

sns.barplot(x=df1['cluster'], y=df1['count'], hue=df1['method'].replace({0: 'control', 1: 'new'}), ax=axis[2])
for i in axis[2].containers:
    axis[2].bar_label(i,)
axis[2].set_title('method vs cluster')
axis[2].set_ylim(0, 100)

plt.tight_layout(w_pad=2);

# %%
standard_scaler = preprocessing.StandardScaler()

# %%
df2 = standard_scaler.fit_transform(df.drop(['cluster'], axis=1))

# %%
df2 = pd.DataFrame(df2, columns=df.drop(['cluster'], axis=1).columns)

# %%
df2.head()
# Out:
#    hour_of_day    method  duration
# 0     0.221520 -1.016808  1.103255
# 1     0.528831 -1.016808  0.402929
# 2    -0.393102  0.983470 -0.193582
# 3     0.221520 -1.016808  0.479797
# 4    -1.315035  0.983470 -1.827321

# %%
linkage_data = linkage(df2, method='ward', metric='euclidean')

# %%
figure, axis = plt.subplots(figsize=(9,4))
dendrogram(linkage_data)
plt.show();

# %% [markdown]
# # Confirmation of Hypothesis

# %%
df['period'] = df.apply(lambda x: '00-08' if x['hour_of_day'] <= 7 else '08-00', axis=1)

# %%
df.head()
# Out:
#    hour_of_day  method    duration  cluster period
# 0           13       0  117.969829        0  08-00
# 1           15       0  106.665437        0  08-00
# 2            9       1   97.036785        1  08-00
# 3           13       0  107.906207        0  08-00
# 4            3       1   70.665614        1  00-08

# %%
import numpy as np

figure, axis = plt.subplots(1, 2, figsize=(14,4), width_ratios=[2,1])

sns.lineplot(x=df['hour_of_day'], y=df['duration'], hue=df['method'].replace({0: 'control', 1: 'new'}), ax=axis[0], estimator=np.median, errorbar=None)
axis[0].set_xticks(np.arange(0,24,1))
axis[0].set_xticklabels(df.sort_values(by="hour_of_day")['hour_of_day'].unique())
axis[0].set_ylim(0, 120)
axis[0].set_ylabel('duration (median)')
axis[0].xaxis.grid()
axis[0].yaxis.grid()

sns.boxplot(x=df['period'], y=df['duration'], hue=df['method'].replace({0: 'control', 1: 'new'}), order=['00-08', '08-00'], ax=axis[1])
axis[1].set_title('duration vs period by method')
axis[1].set_ylim(0, 200)
axis[1].yaxis.grid();

# %%
df['method'] = df['method'].replace({0: 'control', 1: 'new'})

# %%
lr = ols(formula='duration ~ period + method + period*method', data=df)

# %%
lr_result = lr.fit()

# %%
print(lr_result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               duration   R-squared:                       0.354
# Model:                            OLS   Adj. R-squared:                  0.346
# Method:                 Least Squares   F-statistic:                     43.13
# Date:                Sun, 29 Oct 2023   Prob (F-statistic):           2.93e-22
# Time:                        11:58:45   Log-Likelihood:                -955.63
# No. Observations:                 240   AIC:                             1919.
# Df Residuals:                     236   BIC:                             1933.
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                       100.4391      2.068     48.557      0.000      96.364     104.514
# period[T.08-00]                   5.7917      2.544      2.276      0.024       0.780      10.804
# method[T.new]                   -22.3199      2.984     -7.480      0.000     -28.198     -16.441
# period[T.08-00]:method[T.new]    20.1454      3.621      5.563      0.000      13.012      27.279
# ==============================================================================
# Omnibus:                        0.066   Durbin-Watson:                   2.073
# Prob(Omnibus):                  0.967   Jarque-Bera (JB):                0.096
# Skew:                          -0.039   Prob(JB):                        0.953
# Kurtosis:                       2.942   Cond. No.                         8.64
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
