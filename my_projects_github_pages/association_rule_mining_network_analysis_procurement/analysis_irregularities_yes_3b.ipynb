# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
import networkx as nx
import matplotlib.pyplot as plt
import copy

# %%
df1 = pd.read_csv('data_irregularities_yes_2.csv')
df1.head()
# Out:
#      requestor         goods_services      supplier award_date  award_amount
# 0  requestor_a  maintain_facilities_a  supplier_aaa   1-Jan-24   150000.0000
# 1  requestor_a  maintain_facilities_a  supplier_bbb   1-Jan-24   150000.0000
# 2  requestor_a  maintain_facilities_a    supplier_c   1-Jan-24   109847.7126
# 3  requestor_a  maintain_facilities_a  supplier_aaa   1-Apr-24   150000.0000
# 4  requestor_a  maintain_facilities_a  supplier_bbb   1-Apr-24   150000.0000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   requestor       48 non-null     object
#  1   goods_services  48 non-null     object
#  2   supplier        48 non-null     object
#  3   award_date      48 non-null     object
#  4   award_amount    48 non-null     float64
# dtypes: float64(1), object(4)
# memory usage: 2.0+ KB

# %%
df1['award_date_formatted'] = pd.to_datetime(df1['award_date'], format='%d-%b-%y', errors='coerce')
df1.head()
# Out:
#      requestor         goods_services      supplier award_date  award_amount  \
# 0  requestor_a  maintain_facilities_a  supplier_aaa   1-Jan-24   150000.0000
# 1  requestor_a  maintain_facilities_a  supplier_bbb   1-Jan-24   150000.0000
# 2  requestor_a  maintain_facilities_a    supplier_c   1-Jan-24   109847.7126
# 3  requestor_a  maintain_facilities_a  supplier_aaa   1-Apr-24   150000.0000
# 4  requestor_a  maintain_facilities_a  supplier_bbb   1-Apr-24   150000.0000
#
#   award_date_formatted
# 0           2024-01-01
# 1           2024-01-01
# 2           2024-01-01
# 3           2024-04-01
# 4           2024-04-01

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   requestor             48 non-null     object
#  1   goods_services        48 non-null     object
#  2   supplier              48 non-null     object
#  3   award_date            48 non-null     object
#  4   award_amount          48 non-null     float64
#  5   award_date_formatted  48 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 2.4+ KB

# %%
df2 = pd.pivot(df1, index=['requestor','goods_services','award_date'], columns='supplier', values='supplier')
df2.head()
# Out:
# supplier                                     supplier_a  supplier_aaa  \
# requestor   goods_services        award_date
# requestor_a maintain_facilities_a 1-Apr-24          NaN  supplier_aaa
#                                   1-Jan-24          NaN  supplier_aaa
#                                   1-Jul-24          NaN  supplier_aaa
#                                   1-Oct-24          NaN  supplier_aaa
# requestor_b maintain_facilities_b 1-Apr-24          NaN           NaN
#
# supplier                                     supplier_b  supplier_bbb  \
# requestor   goods_services        award_date
# requestor_a maintain_facilities_a 1-Apr-24          NaN  supplier_bbb
#                                   1-Jan-24          NaN  supplier_bbb
#                                   1-Jul-24          NaN  supplier_bbb
#                                   1-Oct-24          NaN  supplier_bbb
# requestor_b maintain_facilities_b 1-Apr-24          NaN           NaN
#
# supplier                                      supplier_c  supplier_d  \
# requestor   goods_services        award_date
# requestor_a maintain_facilities_a 1-Apr-24           NaN         NaN
#                                   1-Jan-24    supplier_c         NaN
#                                   1-Jul-24           NaN         NaN
#                                   1-Oct-24           NaN         NaN
# requestor_b maintain_facilities_b 1-Apr-24           NaN  supplier_d
#
# supplier                                      supplier_e  supplier_f  \
# requestor   goods_services        award_date
# requestor_a maintain_facilities_a 1-Apr-24           NaN  supplier_f
#                                   1-Jan-24           NaN         NaN
#                                   1-Jul-24           NaN         NaN
#                                   1-Oct-24           NaN         NaN
# requestor_b maintain_facilities_b 1-Apr-24    supplier_e  supplier_f
#
# supplier                                     supplier_g supplier_h  \
# requestor   goods_services        award_date
# requestor_a maintain_facilities_a 1-Apr-24          NaN        NaN
#                                   1-Jan-24          NaN        NaN
#                                   1-Jul-24          NaN        NaN
#                                   1-Oct-24          NaN        NaN
# requestor_b maintain_facilities_b 1-Apr-24          NaN        NaN
#
# supplier                                      supplier_i supplier_j  \
# requestor   goods_services        award_date
# requestor_a maintain_facilities_a 1-Apr-24           NaN        NaN
#                                   1-Jan-24           NaN        NaN
#                                   1-Jul-24    supplier_i        NaN
#                                   1-Oct-24           NaN        NaN
# requestor_b maintain_facilities_b 1-Apr-24           NaN        NaN
#
# supplier                                     supplier_k  supplier_l
# requestor   goods_services        award_date
# requestor_a maintain_facilities_a 1-Apr-24          NaN         NaN
#                                   1-Jan-24          NaN         NaN
#                                   1-Jul-24          NaN         NaN
#                                   1-Oct-24          NaN  supplier_l
# requestor_b maintain_facilities_b 1-Apr-24          NaN         NaN

# %%
df3 = pd.DataFrame(df2.to_records())
df3.head()
# Out:
#      requestor         goods_services award_date supplier_a  supplier_aaa  \
# 0  requestor_a  maintain_facilities_a   1-Apr-24        NaN  supplier_aaa
# 1  requestor_a  maintain_facilities_a   1-Jan-24        NaN  supplier_aaa
# 2  requestor_a  maintain_facilities_a   1-Jul-24        NaN  supplier_aaa
# 3  requestor_a  maintain_facilities_a   1-Oct-24        NaN  supplier_aaa
# 4  requestor_b  maintain_facilities_b   1-Apr-24        NaN           NaN
#
#   supplier_b  supplier_bbb  supplier_c  supplier_d  supplier_e  supplier_f  \
# 0        NaN  supplier_bbb         NaN         NaN         NaN  supplier_f
# 1        NaN  supplier_bbb  supplier_c         NaN         NaN         NaN
# 2        NaN  supplier_bbb         NaN         NaN         NaN         NaN
# 3        NaN  supplier_bbb         NaN         NaN         NaN         NaN
# 4        NaN           NaN         NaN  supplier_d  supplier_e  supplier_f
#
#   supplier_g supplier_h  supplier_i supplier_j supplier_k  supplier_l
# 0        NaN        NaN         NaN        NaN        NaN         NaN
# 1        NaN        NaN         NaN        NaN        NaN         NaN
# 2        NaN        NaN  supplier_i        NaN        NaN         NaN
# 3        NaN        NaN         NaN        NaN        NaN  supplier_l
# 4        NaN        NaN         NaN        NaN        NaN         NaN

# %%
df4 = df3.iloc[:,3:].notna()
df4.head()
# Out:
#    supplier_a  supplier_aaa  supplier_b  supplier_bbb  supplier_c  supplier_d  \
# 0       False          True       False          True       False       False
# 1       False          True       False          True        True       False
# 2       False          True       False          True       False       False
# 3       False          True       False          True       False       False
# 4       False         False       False         False       False        True
#
#    supplier_e  supplier_f  supplier_g  supplier_h  supplier_i  supplier_j  \
# 0       False        True       False       False       False       False
# 1       False       False       False       False       False       False
# 2       False       False       False       False        True       False
# 3       False       False       False       False       False       False
# 4        True        True       False       False       False       False
#
#    supplier_k  supplier_l
# 0       False       False
# 1       False       False
# 2       False       False
# 3       False        True
# 4       False       False

# %%
df5 = pd.concat([df3.iloc[:,:3], df4], axis=1)
df5.head()
# Out:
#      requestor         goods_services award_date  supplier_a  supplier_aaa  \
# 0  requestor_a  maintain_facilities_a   1-Apr-24       False          True
# 1  requestor_a  maintain_facilities_a   1-Jan-24       False          True
# 2  requestor_a  maintain_facilities_a   1-Jul-24       False          True
# 3  requestor_a  maintain_facilities_a   1-Oct-24       False          True
# 4  requestor_b  maintain_facilities_b   1-Apr-24       False         False
#
#    supplier_b  supplier_bbb  supplier_c  supplier_d  supplier_e  supplier_f  \
# 0       False          True       False       False       False        True
# 1       False          True        True       False       False       False
# 2       False          True       False       False       False       False
# 3       False          True       False       False       False       False
# 4       False         False       False        True        True        True
#
#    supplier_g  supplier_h  supplier_i  supplier_j  supplier_k  supplier_l
# 0       False       False       False       False       False       False
# 1       False       False       False       False       False       False
# 2       False       False        True       False       False       False
# 3       False       False       False       False       False        True
# 4       False       False       False       False       False       False

# %%
df6 = apriori(df5.iloc[:,3:], min_support=0.1, use_colnames=True)
df6
# Out:
#     support                              itemsets
# 0    0.1875                          (supplier_a)
# 1    0.2500                        (supplier_aaa)
# 2    0.1875                          (supplier_b)
# 3    0.2500                        (supplier_bbb)
# 4    0.2500                          (supplier_c)
# 5    0.1875                          (supplier_d)
# 6    0.1875                          (supplier_e)
# 7    0.2500                          (supplier_f)
# 8    0.1875                          (supplier_g)
# 9    0.1875                          (supplier_h)
# 10   0.2500                          (supplier_i)
# 11   0.1875                          (supplier_j)
# 12   0.1875                          (supplier_k)
# 13   0.2500                          (supplier_l)
# 14   0.1875              (supplier_a, supplier_b)
# 15   0.1875              (supplier_a, supplier_c)
# 16   0.2500          (supplier_aaa, supplier_bbb)
# 17   0.1875              (supplier_b, supplier_c)
# 18   0.1875              (supplier_d, supplier_e)
# 19   0.1875              (supplier_f, supplier_d)
# 20   0.1875              (supplier_f, supplier_e)
# 21   0.1875              (supplier_g, supplier_h)
# 22   0.1875              (supplier_g, supplier_i)
# 23   0.1875              (supplier_h, supplier_i)
# 24   0.1875              (supplier_k, supplier_j)
# 25   0.1875              (supplier_j, supplier_l)
# 26   0.1875              (supplier_k, supplier_l)
# 27   0.1875  (supplier_a, supplier_c, supplier_b)
# 28   0.1875  (supplier_f, supplier_d, supplier_e)
# 29   0.1875  (supplier_g, supplier_h, supplier_i)
# 30   0.1875  (supplier_k, supplier_j, supplier_l)

# %%
df7 = association_rules(df6, metric='confidence', min_threshold=0.1, support_only=False)
df7 = df7.sort_values(['confidence','lift'], ascending=[False,False])
df7
# Out:
#                  antecedents               consequents  antecedent support  \
# 0               (supplier_a)              (supplier_b)              0.1875
# 1               (supplier_b)              (supplier_a)              0.1875
# 8               (supplier_d)              (supplier_e)              0.1875
# 9               (supplier_e)              (supplier_d)              0.1875
# 14              (supplier_g)              (supplier_h)              0.1875
# 15              (supplier_h)              (supplier_g)              0.1875
# 20              (supplier_k)              (supplier_j)              0.1875
# 21              (supplier_j)              (supplier_k)              0.1875
# 26  (supplier_a, supplier_c)              (supplier_b)              0.1875
# 28  (supplier_b, supplier_c)              (supplier_a)              0.1875
# 29              (supplier_a)  (supplier_b, supplier_c)              0.1875
# 31              (supplier_b)  (supplier_a, supplier_c)              0.1875
# 32  (supplier_f, supplier_d)              (supplier_e)              0.1875
# 33  (supplier_f, supplier_e)              (supplier_d)              0.1875
# 36              (supplier_d)  (supplier_f, supplier_e)              0.1875
# 37              (supplier_e)  (supplier_f, supplier_d)              0.1875
# 39  (supplier_g, supplier_i)              (supplier_h)              0.1875
# 40  (supplier_h, supplier_i)              (supplier_g)              0.1875
# 41              (supplier_g)  (supplier_h, supplier_i)              0.1875
# 42              (supplier_h)  (supplier_g, supplier_i)              0.1875
# 45  (supplier_k, supplier_l)              (supplier_j)              0.1875
# 46  (supplier_j, supplier_l)              (supplier_k)              0.1875
# 47              (supplier_k)  (supplier_j, supplier_l)              0.1875
# 48              (supplier_j)  (supplier_k, supplier_l)              0.1875
# 2               (supplier_a)              (supplier_c)              0.1875
# 4             (supplier_aaa)            (supplier_bbb)              0.2500
# 5             (supplier_bbb)            (supplier_aaa)              0.2500
# 6               (supplier_b)              (supplier_c)              0.1875
# 11              (supplier_d)              (supplier_f)              0.1875
# 13              (supplier_e)              (supplier_f)              0.1875
# 16              (supplier_g)              (supplier_i)              0.1875
# 18              (supplier_h)              (supplier_i)              0.1875
# 22              (supplier_j)              (supplier_l)              0.1875
# 24              (supplier_k)              (supplier_l)              0.1875
# 27  (supplier_a, supplier_b)              (supplier_c)              0.1875
# 34  (supplier_d, supplier_e)              (supplier_f)              0.1875
# 38  (supplier_g, supplier_h)              (supplier_i)              0.1875
# 44  (supplier_j, supplier_k)              (supplier_l)              0.1875
# 3               (supplier_c)              (supplier_a)              0.2500
# 7               (supplier_c)              (supplier_b)              0.2500
# 10              (supplier_f)              (supplier_d)              0.2500
# 12              (supplier_f)              (supplier_e)              0.2500
# 17              (supplier_i)              (supplier_g)              0.2500
# 19              (supplier_i)              (supplier_h)              0.2500
# 23              (supplier_l)              (supplier_j)              0.2500
# 25              (supplier_l)              (supplier_k)              0.2500
# 30              (supplier_c)  (supplier_a, supplier_b)              0.2500
# 35              (supplier_f)  (supplier_d, supplier_e)              0.2500
# 43              (supplier_i)  (supplier_g, supplier_h)              0.2500
# 49              (supplier_l)  (supplier_j, supplier_k)              0.2500
#
#     consequent support  support  confidence      lift  leverage  conviction  \
# 0               0.1875   0.1875        1.00  5.333333  0.152344         inf
# 1               0.1875   0.1875        1.00  5.333333  0.152344         inf
# 8               0.1875   0.1875        1.00  5.333333  0.152344         inf
# 9               0.1875   0.1875        1.00  5.333333  0.152344         inf
# 14              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 15              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 20              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 21              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 26              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 28              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 29              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 31              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 32              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 33              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 36              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 37              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 39              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 40              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 41              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 42              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 45              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 46              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 47              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 48              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 2               0.2500   0.1875        1.00  4.000000  0.140625         inf
# 4               0.2500   0.2500        1.00  4.000000  0.187500         inf
# 5               0.2500   0.2500        1.00  4.000000  0.187500         inf
# 6               0.2500   0.1875        1.00  4.000000  0.140625         inf
# 11              0.2500   0.1875        1.00  4.000000  0.140625         inf
# 13              0.2500   0.1875        1.00  4.000000  0.140625         inf
# 16              0.2500   0.1875        1.00  4.000000  0.140625         inf
# 18              0.2500   0.1875        1.00  4.000000  0.140625         inf
# 22              0.2500   0.1875        1.00  4.000000  0.140625         inf
# 24              0.2500   0.1875        1.00  4.000000  0.140625         inf
# 27              0.2500   0.1875        1.00  4.000000  0.140625         inf
# 34              0.2500   0.1875        1.00  4.000000  0.140625         inf
# 38              0.2500   0.1875        1.00  4.000000  0.140625         inf
# 44              0.2500   0.1875        1.00  4.000000  0.140625         inf
# 3               0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 7               0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 10              0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 12              0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 17              0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 19              0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 23              0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 25              0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 30              0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 35              0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 43              0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 49              0.1875   0.1875        0.75  4.000000  0.140625        3.25
#
#     zhangs_metric
# 0        1.000000
# 1        1.000000
# 8        1.000000
# 9        1.000000
# 14       1.000000
# 15       1.000000
# 20       1.000000
# 21       1.000000
# 26       1.000000
# 28       1.000000
# 29       1.000000
# 31       1.000000
# 32       1.000000
# 33       1.000000
# 36       1.000000
# 37       1.000000
# 39       1.000000
# 40       1.000000
# 41       1.000000
# 42       1.000000
# 45       1.000000
# 46       1.000000
# 47       1.000000
# 48       1.000000
# 2        0.923077
# 4        1.000000
# 5        1.000000
# 6        0.923077
# 11       0.923077
# 13       0.923077
# 16       0.923077
# 18       0.923077
# 22       0.923077
# 24       0.923077
# 27       0.923077
# 34       0.923077
# 38       0.923077
# 44       0.923077
# 3        1.000000
# 7        1.000000
# 10       1.000000
# 12       1.000000
# 17       1.000000
# 19       1.000000
# 23       1.000000
# 25       1.000000
# 30       1.000000
# 35       1.000000
# 43       1.000000
# 49       1.000000

# %%
df7['antecedents'] = df7['antecedents'].apply(lambda x: list(x))
df7['consequents'] = df7['consequents'].apply(lambda x: list(x))
df7
# Out:
#                  antecedents               consequents  antecedent support  \
# 0               [supplier_a]              [supplier_b]              0.1875
# 1               [supplier_b]              [supplier_a]              0.1875
# 8               [supplier_d]              [supplier_e]              0.1875
# 9               [supplier_e]              [supplier_d]              0.1875
# 14              [supplier_g]              [supplier_h]              0.1875
# 15              [supplier_h]              [supplier_g]              0.1875
# 20              [supplier_k]              [supplier_j]              0.1875
# 21              [supplier_j]              [supplier_k]              0.1875
# 26  [supplier_a, supplier_c]              [supplier_b]              0.1875
# 28  [supplier_b, supplier_c]              [supplier_a]              0.1875
# 29              [supplier_a]  [supplier_b, supplier_c]              0.1875
# 31              [supplier_b]  [supplier_a, supplier_c]              0.1875
# 32  [supplier_f, supplier_d]              [supplier_e]              0.1875
# 33  [supplier_f, supplier_e]              [supplier_d]              0.1875
# 36              [supplier_d]  [supplier_f, supplier_e]              0.1875
# 37              [supplier_e]  [supplier_f, supplier_d]              0.1875
# 39  [supplier_g, supplier_i]              [supplier_h]              0.1875
# 40  [supplier_h, supplier_i]              [supplier_g]              0.1875
# 41              [supplier_g]  [supplier_h, supplier_i]              0.1875
# 42              [supplier_h]  [supplier_g, supplier_i]              0.1875
# 45  [supplier_k, supplier_l]              [supplier_j]              0.1875
# 46  [supplier_j, supplier_l]              [supplier_k]              0.1875
# 47              [supplier_k]  [supplier_j, supplier_l]              0.1875
# 48              [supplier_j]  [supplier_k, supplier_l]              0.1875
# 2               [supplier_a]              [supplier_c]              0.1875
# 4             [supplier_aaa]            [supplier_bbb]              0.2500
# 5             [supplier_bbb]            [supplier_aaa]              0.2500
# 6               [supplier_b]              [supplier_c]              0.1875
# 11              [supplier_d]              [supplier_f]              0.1875
# 13              [supplier_e]              [supplier_f]              0.1875
# 16              [supplier_g]              [supplier_i]              0.1875
# 18              [supplier_h]              [supplier_i]              0.1875
# 22              [supplier_j]              [supplier_l]              0.1875
# 24              [supplier_k]              [supplier_l]              0.1875
# 27  [supplier_a, supplier_b]              [supplier_c]              0.1875
# 34  [supplier_d, supplier_e]              [supplier_f]              0.1875
# 38  [supplier_g, supplier_h]              [supplier_i]              0.1875
# 44  [supplier_j, supplier_k]              [supplier_l]              0.1875
# 3               [supplier_c]              [supplier_a]              0.2500
# 7               [supplier_c]              [supplier_b]              0.2500
# 10              [supplier_f]              [supplier_d]              0.2500
# 12              [supplier_f]              [supplier_e]              0.2500
# 17              [supplier_i]              [supplier_g]              0.2500
# 19              [supplier_i]              [supplier_h]              0.2500
# 23              [supplier_l]              [supplier_j]              0.2500
# 25              [supplier_l]              [supplier_k]              0.2500
# 30              [supplier_c]  [supplier_a, supplier_b]              0.2500
# 35              [supplier_f]  [supplier_d, supplier_e]              0.2500
# 43              [supplier_i]  [supplier_g, supplier_h]              0.2500
# 49              [supplier_l]  [supplier_j, supplier_k]              0.2500
#
#     consequent support  support  confidence      lift  leverage  conviction  \
# 0               0.1875   0.1875        1.00  5.333333  0.152344         inf
# 1               0.1875   0.1875        1.00  5.333333  0.152344         inf
# 8               0.1875   0.1875        1.00  5.333333  0.152344         inf
# 9               0.1875   0.1875        1.00  5.333333  0.152344         inf
# 14              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 15              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 20              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 21              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 26              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 28              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 29              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 31              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 32              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 33              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 36              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 37              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 39              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 40              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 41              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 42              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 45              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 46              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 47              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 48              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 2               0.2500   0.1875        1.00  4.000000  0.140625         inf
# 4               0.2500   0.2500        1.00  4.000000  0.187500         inf
# 5               0.2500   0.2500        1.00  4.000000  0.187500         inf
# 6               0.2500   0.1875        1.00  4.000000  0.140625         inf
# 11              0.2500   0.1875        1.00  4.000000  0.140625         inf
# 13              0.2500   0.1875        1.00  4.000000  0.140625         inf
# 16              0.2500   0.1875        1.00  4.000000  0.140625         inf
# 18              0.2500   0.1875        1.00  4.000000  0.140625         inf
# 22              0.2500   0.1875        1.00  4.000000  0.140625         inf
# 24              0.2500   0.1875        1.00  4.000000  0.140625         inf
# 27              0.2500   0.1875        1.00  4.000000  0.140625         inf
# 34              0.2500   0.1875        1.00  4.000000  0.140625         inf
# 38              0.2500   0.1875        1.00  4.000000  0.140625         inf
# 44              0.2500   0.1875        1.00  4.000000  0.140625         inf
# 3               0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 7               0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 10              0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 12              0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 17              0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 19              0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 23              0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 25              0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 30              0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 35              0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 43              0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 49              0.1875   0.1875        0.75  4.000000  0.140625        3.25
#
#     zhangs_metric
# 0        1.000000
# 1        1.000000
# 8        1.000000
# 9        1.000000
# 14       1.000000
# 15       1.000000
# 20       1.000000
# 21       1.000000
# 26       1.000000
# 28       1.000000
# 29       1.000000
# 31       1.000000
# 32       1.000000
# 33       1.000000
# 36       1.000000
# 37       1.000000
# 39       1.000000
# 40       1.000000
# 41       1.000000
# 42       1.000000
# 45       1.000000
# 46       1.000000
# 47       1.000000
# 48       1.000000
# 2        0.923077
# 4        1.000000
# 5        1.000000
# 6        0.923077
# 11       0.923077
# 13       0.923077
# 16       0.923077
# 18       0.923077
# 22       0.923077
# 24       0.923077
# 27       0.923077
# 34       0.923077
# 38       0.923077
# 44       0.923077
# 3        1.000000
# 7        1.000000
# 10       1.000000
# 12       1.000000
# 17       1.000000
# 19       1.000000
# 23       1.000000
# 25       1.000000
# 30       1.000000
# 35       1.000000
# 43       1.000000
# 49       1.000000

# %%
df7['antecedents'] = df7['antecedents'].apply(lambda x: ', '.join(x))
df7['consequents'] = df7['consequents'].apply(lambda x: ', '.join(x))
df7
# Out:
#                antecedents             consequents  antecedent support  \
# 0               supplier_a              supplier_b              0.1875
# 1               supplier_b              supplier_a              0.1875
# 8               supplier_d              supplier_e              0.1875
# 9               supplier_e              supplier_d              0.1875
# 14              supplier_g              supplier_h              0.1875
# 15              supplier_h              supplier_g              0.1875
# 20              supplier_k              supplier_j              0.1875
# 21              supplier_j              supplier_k              0.1875
# 26  supplier_a, supplier_c              supplier_b              0.1875
# 28  supplier_b, supplier_c              supplier_a              0.1875
# 29              supplier_a  supplier_b, supplier_c              0.1875
# 31              supplier_b  supplier_a, supplier_c              0.1875
# 32  supplier_f, supplier_d              supplier_e              0.1875
# 33  supplier_f, supplier_e              supplier_d              0.1875
# 36              supplier_d  supplier_f, supplier_e              0.1875
# 37              supplier_e  supplier_f, supplier_d              0.1875
# 39  supplier_g, supplier_i              supplier_h              0.1875
# 40  supplier_h, supplier_i              supplier_g              0.1875
# 41              supplier_g  supplier_h, supplier_i              0.1875
# 42              supplier_h  supplier_g, supplier_i              0.1875
# 45  supplier_k, supplier_l              supplier_j              0.1875
# 46  supplier_j, supplier_l              supplier_k              0.1875
# 47              supplier_k  supplier_j, supplier_l              0.1875
# 48              supplier_j  supplier_k, supplier_l              0.1875
# 2               supplier_a              supplier_c              0.1875
# 4             supplier_aaa            supplier_bbb              0.2500
# 5             supplier_bbb            supplier_aaa              0.2500
# 6               supplier_b              supplier_c              0.1875
# 11              supplier_d              supplier_f              0.1875
# 13              supplier_e              supplier_f              0.1875
# 16              supplier_g              supplier_i              0.1875
# 18              supplier_h              supplier_i              0.1875
# 22              supplier_j              supplier_l              0.1875
# 24              supplier_k              supplier_l              0.1875
# 27  supplier_a, supplier_b              supplier_c              0.1875
# 34  supplier_d, supplier_e              supplier_f              0.1875
# 38  supplier_g, supplier_h              supplier_i              0.1875
# 44  supplier_j, supplier_k              supplier_l              0.1875
# 3               supplier_c              supplier_a              0.2500
# 7               supplier_c              supplier_b              0.2500
# 10              supplier_f              supplier_d              0.2500
# 12              supplier_f              supplier_e              0.2500
# 17              supplier_i              supplier_g              0.2500
# 19              supplier_i              supplier_h              0.2500
# 23              supplier_l              supplier_j              0.2500
# 25              supplier_l              supplier_k              0.2500
# 30              supplier_c  supplier_a, supplier_b              0.2500
# 35              supplier_f  supplier_d, supplier_e              0.2500
# 43              supplier_i  supplier_g, supplier_h              0.2500
# 49              supplier_l  supplier_j, supplier_k              0.2500
#
#     consequent support  support  confidence      lift  leverage  conviction  \
# 0               0.1875   0.1875        1.00  5.333333  0.152344         inf
# 1               0.1875   0.1875        1.00  5.333333  0.152344         inf
# 8               0.1875   0.1875        1.00  5.333333  0.152344         inf
# 9               0.1875   0.1875        1.00  5.333333  0.152344         inf
# 14              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 15              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 20              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 21              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 26              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 28              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 29              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 31              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 32              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 33              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 36              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 37              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 39              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 40              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 41              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 42              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 45              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 46              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 47              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 48              0.1875   0.1875        1.00  5.333333  0.152344         inf
# 2               0.2500   0.1875        1.00  4.000000  0.140625         inf
# 4               0.2500   0.2500        1.00  4.000000  0.187500         inf
# 5               0.2500   0.2500        1.00  4.000000  0.187500         inf
# 6               0.2500   0.1875        1.00  4.000000  0.140625         inf
# 11              0.2500   0.1875        1.00  4.000000  0.140625         inf
# 13              0.2500   0.1875        1.00  4.000000  0.140625         inf
# 16              0.2500   0.1875        1.00  4.000000  0.140625         inf
# 18              0.2500   0.1875        1.00  4.000000  0.140625         inf
# 22              0.2500   0.1875        1.00  4.000000  0.140625         inf
# 24              0.2500   0.1875        1.00  4.000000  0.140625         inf
# 27              0.2500   0.1875        1.00  4.000000  0.140625         inf
# 34              0.2500   0.1875        1.00  4.000000  0.140625         inf
# 38              0.2500   0.1875        1.00  4.000000  0.140625         inf
# 44              0.2500   0.1875        1.00  4.000000  0.140625         inf
# 3               0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 7               0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 10              0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 12              0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 17              0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 19              0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 23              0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 25              0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 30              0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 35              0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 43              0.1875   0.1875        0.75  4.000000  0.140625        3.25
# 49              0.1875   0.1875        0.75  4.000000  0.140625        3.25
#
#     zhangs_metric
# 0        1.000000
# 1        1.000000
# 8        1.000000
# 9        1.000000
# 14       1.000000
# 15       1.000000
# 20       1.000000
# 21       1.000000
# 26       1.000000
# 28       1.000000
# 29       1.000000
# 31       1.000000
# 32       1.000000
# 33       1.000000
# 36       1.000000
# 37       1.000000
# 39       1.000000
# 40       1.000000
# 41       1.000000
# 42       1.000000
# 45       1.000000
# 46       1.000000
# 47       1.000000
# 48       1.000000
# 2        0.923077
# 4        1.000000
# 5        1.000000
# 6        0.923077
# 11       0.923077
# 13       0.923077
# 16       0.923077
# 18       0.923077
# 22       0.923077
# 24       0.923077
# 27       0.923077
# 34       0.923077
# 38       0.923077
# 44       0.923077
# 3        1.000000
# 7        1.000000
# 10       1.000000
# 12       1.000000
# 17       1.000000
# 19       1.000000
# 23       1.000000
# 25       1.000000
# 30       1.000000
# 35       1.000000
# 43       1.000000
# 49       1.000000

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   antecedents         50 non-null     object
#  1   consequents         50 non-null     object
#  2   antecedent support  50 non-null     float64
#  3   consequent support  50 non-null     float64
#  4   support             50 non-null     float64
#  5   confidence          50 non-null     float64
#  6   lift                50 non-null     float64
#  7   leverage            50 non-null     float64
#  8   conviction          50 non-null     float64
#  9   zhangs_metric       50 non-null     float64
# dtypes: float64(8), object(2)
# memory usage: 4.3+ KB

# %%
G = nx.Graph()

# %%
for item in df7['antecedents']:
    G.add_node(item)
for item in df7['consequents']:
    G.add_node(item)

# %%
for idx, row in df7.iterrows():
    # G.add_edge(row['antecedents']), row['consequents']), label=f"Confidence: {row['confidence']:.2f}")
    G.add_edge(row['antecedents'], row['consequents'])

# %%
pos = nx.spring_layout(G, k=1)

# %%
fig, ax = plt.subplots(figsize=(13,9))
# edge_labels = nx.get_edge_attributes(G, 'label')
nx.draw(G, pos, with_labels=True, node_size=250, node_color='pink', font_size=10)
# nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)
plt.title("Connections in Network", fontsize=15)
plt.show()

# %%
# community identification using Louvain algorithm
communities = nx.community.louvain_communities(G, seed=42)

# print the communities and the number of nodes in each community
i = 1
for c in communities:
    print(f'Community {i}: {c}')
    i = i + 1
    print(f'Number of nodes: {len(c)}')
    print()
print()

color_map = []
for node in G.nodes():
    for i in range(len(communities)):
        if node in communities[i]:
            color_map.append(i)

print("Graph with communities marked:")
print()

fig, ax = plt.subplots(figsize=(13,9))
pos = nx.spring_layout(G, k=1)
nx.draw(G, pos, node_color=color_map, with_labels=True, font_size=10, node_size=250)
plt.title("Communities in Network", fontsize=15)
plt.show()
# Out:
# Community 1: {'supplier_b', 'supplier_a', 'supplier_b, supplier_c', 'supplier_a, supplier_c', 'supplier_c', 'supplier_a, supplier_b'}
# Number of nodes: 6
#
# Community 2: {'supplier_f, supplier_e', 'supplier_d, supplier_e', 'supplier_f, supplier_d', 'supplier_f', 'supplier_d', 'supplier_e'}
# Number of nodes: 6
#
# Community 3: {'supplier_g, supplier_i', 'supplier_i', 'supplier_g', 'supplier_g, supplier_h', 'supplier_h', 'supplier_h, supplier_i'}
# Number of nodes: 6
#
# Community 4: {'supplier_k', 'supplier_j', 'supplier_j, supplier_k', 'supplier_l', 'supplier_j, supplier_l', 'supplier_k, supplier_l'}
# Number of nodes: 6
#
# Community 5: {'supplier_aaa', 'supplier_bbb'}
# Number of nodes: 2
#
#
# Graph with communities marked:
