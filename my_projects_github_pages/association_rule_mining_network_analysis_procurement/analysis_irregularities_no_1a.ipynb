# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
import networkx as nx
import matplotlib.pyplot as plt
import copy

# %%
df1 = pd.read_csv('data_irregularities_no.csv')
df1.head()
# Out:
#      requestor         goods_services    supplier award_date  award_amount
# 0  requestor_a  maintain_facilities_a  supplier_a   1-Jan-24   100128.7881
# 1  requestor_a  maintain_facilities_a  supplier_b   1-Jan-24   100228.2785
# 2  requestor_a  maintain_facilities_a  supplier_c   1-Jan-24   109847.7126
# 3  requestor_a  maintain_facilities_a  supplier_d   1-Apr-24   109727.4697
# 4  requestor_a  maintain_facilities_a  supplier_e   1-Apr-24   103403.4242

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   requestor       48 non-null     object
#  1   goods_services  48 non-null     object
#  2   supplier        48 non-null     object
#  3   award_date      48 non-null     object
#  4   award_amount    48 non-null     float64
# dtypes: float64(1), object(4)
# memory usage: 2.0+ KB

# %%
df1['award_date_formatted'] = pd.to_datetime(df1['award_date'], format='%d-%b-%y', errors='coerce')
df1.head()
# Out:
#      requestor         goods_services    supplier award_date  award_amount  \
# 0  requestor_a  maintain_facilities_a  supplier_a   1-Jan-24   100128.7881
# 1  requestor_a  maintain_facilities_a  supplier_b   1-Jan-24   100228.2785
# 2  requestor_a  maintain_facilities_a  supplier_c   1-Jan-24   109847.7126
# 3  requestor_a  maintain_facilities_a  supplier_d   1-Apr-24   109727.4697
# 4  requestor_a  maintain_facilities_a  supplier_e   1-Apr-24   103403.4242
#
#   award_date_formatted
# 0           2024-01-01
# 1           2024-01-01
# 2           2024-01-01
# 3           2024-04-01
# 4           2024-04-01

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   requestor             48 non-null     object
#  1   goods_services        48 non-null     object
#  2   supplier              48 non-null     object
#  3   award_date            48 non-null     object
#  4   award_amount          48 non-null     float64
#  5   award_date_formatted  48 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 2.4+ KB

# %%
df2 = pd.pivot(df1, index=['requestor','goods_services','award_date'], columns='supplier', values='supplier')
df2.head()
# Out:
# supplier                                      supplier_a  supplier_b  \
# requestor   goods_services        award_date
# requestor_a maintain_facilities_a 1-Apr-24           NaN         NaN
#                                   1-Jan-24    supplier_a  supplier_b
#                                   1-Jul-24           NaN         NaN
#                                   1-Oct-24           NaN         NaN
# requestor_b maintain_facilities_b 1-Apr-24           NaN         NaN
#
# supplier                                      supplier_c  supplier_d  \
# requestor   goods_services        award_date
# requestor_a maintain_facilities_a 1-Apr-24           NaN  supplier_d
#                                   1-Jan-24    supplier_c         NaN
#                                   1-Jul-24           NaN         NaN
#                                   1-Oct-24           NaN         NaN
# requestor_b maintain_facilities_b 1-Apr-24           NaN  supplier_d
#
# supplier                                      supplier_e  supplier_f  \
# requestor   goods_services        award_date
# requestor_a maintain_facilities_a 1-Apr-24    supplier_e  supplier_f
#                                   1-Jan-24           NaN         NaN
#                                   1-Jul-24           NaN         NaN
#                                   1-Oct-24           NaN         NaN
# requestor_b maintain_facilities_b 1-Apr-24    supplier_e  supplier_f
#
# supplier                                      supplier_g  supplier_h  \
# requestor   goods_services        award_date
# requestor_a maintain_facilities_a 1-Apr-24           NaN         NaN
#                                   1-Jan-24           NaN         NaN
#                                   1-Jul-24    supplier_g  supplier_h
#                                   1-Oct-24           NaN         NaN
# requestor_b maintain_facilities_b 1-Apr-24           NaN         NaN
#
# supplier                                      supplier_i  supplier_j  \
# requestor   goods_services        award_date
# requestor_a maintain_facilities_a 1-Apr-24           NaN         NaN
#                                   1-Jan-24           NaN         NaN
#                                   1-Jul-24    supplier_i         NaN
#                                   1-Oct-24           NaN  supplier_j
# requestor_b maintain_facilities_b 1-Apr-24           NaN         NaN
#
# supplier                                      supplier_k  supplier_l
# requestor   goods_services        award_date
# requestor_a maintain_facilities_a 1-Apr-24           NaN         NaN
#                                   1-Jan-24           NaN         NaN
#                                   1-Jul-24           NaN         NaN
#                                   1-Oct-24    supplier_k  supplier_l
# requestor_b maintain_facilities_b 1-Apr-24           NaN         NaN

# %%
df3 = pd.DataFrame(df2.to_records())
df3.head()
# Out:
#      requestor         goods_services award_date  supplier_a  supplier_b  \
# 0  requestor_a  maintain_facilities_a   1-Apr-24         NaN         NaN
# 1  requestor_a  maintain_facilities_a   1-Jan-24  supplier_a  supplier_b
# 2  requestor_a  maintain_facilities_a   1-Jul-24         NaN         NaN
# 3  requestor_a  maintain_facilities_a   1-Oct-24         NaN         NaN
# 4  requestor_b  maintain_facilities_b   1-Apr-24         NaN         NaN
#
#    supplier_c  supplier_d  supplier_e  supplier_f  supplier_g  supplier_h  \
# 0         NaN  supplier_d  supplier_e  supplier_f         NaN         NaN
# 1  supplier_c         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN  supplier_g  supplier_h
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN  supplier_d  supplier_e  supplier_f         NaN         NaN
#
#    supplier_i  supplier_j  supplier_k  supplier_l
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# 2  supplier_i         NaN         NaN         NaN
# 3         NaN  supplier_j  supplier_k  supplier_l
# 4         NaN         NaN         NaN         NaN

# %%
df4 = df3.iloc[:,3:].notna()
df4.head()
# Out:
#    supplier_a  supplier_b  supplier_c  supplier_d  supplier_e  supplier_f  \
# 0       False       False       False        True        True        True
# 1        True        True        True       False       False       False
# 2       False       False       False       False       False       False
# 3       False       False       False       False       False       False
# 4       False       False       False        True        True        True
#
#    supplier_g  supplier_h  supplier_i  supplier_j  supplier_k  supplier_l
# 0       False       False       False       False       False       False
# 1       False       False       False       False       False       False
# 2        True        True        True       False       False       False
# 3       False       False       False        True        True        True
# 4       False       False       False       False       False       False

# %%
df5 = pd.concat([df3.iloc[:,:3], df4], axis=1)
df5.head()
# Out:
#      requestor         goods_services award_date  supplier_a  supplier_b  \
# 0  requestor_a  maintain_facilities_a   1-Apr-24       False       False
# 1  requestor_a  maintain_facilities_a   1-Jan-24        True        True
# 2  requestor_a  maintain_facilities_a   1-Jul-24       False       False
# 3  requestor_a  maintain_facilities_a   1-Oct-24       False       False
# 4  requestor_b  maintain_facilities_b   1-Apr-24       False       False
#
#    supplier_c  supplier_d  supplier_e  supplier_f  supplier_g  supplier_h  \
# 0       False        True        True        True       False       False
# 1        True       False       False       False       False       False
# 2       False       False       False       False        True        True
# 3       False       False       False       False       False       False
# 4       False        True        True        True       False       False
#
#    supplier_i  supplier_j  supplier_k  supplier_l
# 0       False       False       False       False
# 1       False       False       False       False
# 2        True       False       False       False
# 3       False        True        True        True
# 4       False       False       False       False

# %%
df6 = apriori(df5.iloc[:,3:], min_support=0.1, use_colnames=True)
df6
# Out:
#     support                              itemsets
# 0      0.25                          (supplier_a)
# 1      0.25                          (supplier_b)
# 2      0.25                          (supplier_c)
# 3      0.25                          (supplier_d)
# 4      0.25                          (supplier_e)
# 5      0.25                          (supplier_f)
# 6      0.25                          (supplier_g)
# 7      0.25                          (supplier_h)
# 8      0.25                          (supplier_i)
# 9      0.25                          (supplier_j)
# 10     0.25                          (supplier_k)
# 11     0.25                          (supplier_l)
# 12     0.25              (supplier_b, supplier_a)
# 13     0.25              (supplier_a, supplier_c)
# 14     0.25              (supplier_b, supplier_c)
# 15     0.25              (supplier_d, supplier_e)
# 16     0.25              (supplier_f, supplier_d)
# 17     0.25              (supplier_f, supplier_e)
# 18     0.25              (supplier_h, supplier_g)
# 19     0.25              (supplier_i, supplier_g)
# 20     0.25              (supplier_h, supplier_i)
# 21     0.25              (supplier_k, supplier_j)
# 22     0.25              (supplier_l, supplier_j)
# 23     0.25              (supplier_k, supplier_l)
# 24     0.25  (supplier_b, supplier_a, supplier_c)
# 25     0.25  (supplier_f, supplier_d, supplier_e)
# 26     0.25  (supplier_h, supplier_i, supplier_g)
# 27     0.25  (supplier_k, supplier_l, supplier_j)

# %%
df7 = association_rules(df6, metric='confidence', min_threshold=0.1, support_only=False)
df7 = df7.sort_values(['confidence','lift'], ascending=[False,False])
df7
# Out:
#                  antecedents               consequents  antecedent support  \
# 0               (supplier_b)              (supplier_a)                0.25
# 1               (supplier_a)              (supplier_b)                0.25
# 2               (supplier_a)              (supplier_c)                0.25
# 3               (supplier_c)              (supplier_a)                0.25
# 4               (supplier_b)              (supplier_c)                0.25
# 5               (supplier_c)              (supplier_b)                0.25
# 6               (supplier_d)              (supplier_e)                0.25
# 7               (supplier_e)              (supplier_d)                0.25
# 8               (supplier_f)              (supplier_d)                0.25
# 9               (supplier_d)              (supplier_f)                0.25
# 10              (supplier_f)              (supplier_e)                0.25
# 11              (supplier_e)              (supplier_f)                0.25
# 12              (supplier_h)              (supplier_g)                0.25
# 13              (supplier_g)              (supplier_h)                0.25
# 14              (supplier_i)              (supplier_g)                0.25
# 15              (supplier_g)              (supplier_i)                0.25
# 16              (supplier_h)              (supplier_i)                0.25
# 17              (supplier_i)              (supplier_h)                0.25
# 18              (supplier_k)              (supplier_j)                0.25
# 19              (supplier_j)              (supplier_k)                0.25
# 20              (supplier_l)              (supplier_j)                0.25
# 21              (supplier_j)              (supplier_l)                0.25
# 22              (supplier_k)              (supplier_l)                0.25
# 23              (supplier_l)              (supplier_k)                0.25
# 24  (supplier_a, supplier_b)              (supplier_c)                0.25
# 25  (supplier_b, supplier_c)              (supplier_a)                0.25
# 26  (supplier_a, supplier_c)              (supplier_b)                0.25
# 27              (supplier_b)  (supplier_a, supplier_c)                0.25
# 28              (supplier_a)  (supplier_b, supplier_c)                0.25
# 29              (supplier_c)  (supplier_a, supplier_b)                0.25
# 30  (supplier_f, supplier_d)              (supplier_e)                0.25
# 31  (supplier_f, supplier_e)              (supplier_d)                0.25
# 32  (supplier_d, supplier_e)              (supplier_f)                0.25
# 33              (supplier_f)  (supplier_d, supplier_e)                0.25
# 34              (supplier_d)  (supplier_f, supplier_e)                0.25
# 35              (supplier_e)  (supplier_f, supplier_d)                0.25
# 36  (supplier_h, supplier_i)              (supplier_g)                0.25
# 37  (supplier_h, supplier_g)              (supplier_i)                0.25
# 38  (supplier_i, supplier_g)              (supplier_h)                0.25
# 39              (supplier_h)  (supplier_i, supplier_g)                0.25
# 40              (supplier_i)  (supplier_h, supplier_g)                0.25
# 41              (supplier_g)  (supplier_h, supplier_i)                0.25
# 42  (supplier_k, supplier_l)              (supplier_j)                0.25
# 43  (supplier_k, supplier_j)              (supplier_l)                0.25
# 44  (supplier_l, supplier_j)              (supplier_k)                0.25
# 45              (supplier_k)  (supplier_l, supplier_j)                0.25
# 46              (supplier_l)  (supplier_k, supplier_j)                0.25
# 47              (supplier_j)  (supplier_k, supplier_l)                0.25
#
#     consequent support  support  confidence  lift  leverage  conviction  \
# 0                 0.25     0.25         1.0   4.0    0.1875         inf
# 1                 0.25     0.25         1.0   4.0    0.1875         inf
# 2                 0.25     0.25         1.0   4.0    0.1875         inf
# 3                 0.25     0.25         1.0   4.0    0.1875         inf
# 4                 0.25     0.25         1.0   4.0    0.1875         inf
# 5                 0.25     0.25         1.0   4.0    0.1875         inf
# 6                 0.25     0.25         1.0   4.0    0.1875         inf
# 7                 0.25     0.25         1.0   4.0    0.1875         inf
# 8                 0.25     0.25         1.0   4.0    0.1875         inf
# 9                 0.25     0.25         1.0   4.0    0.1875         inf
# 10                0.25     0.25         1.0   4.0    0.1875         inf
# 11                0.25     0.25         1.0   4.0    0.1875         inf
# 12                0.25     0.25         1.0   4.0    0.1875         inf
# 13                0.25     0.25         1.0   4.0    0.1875         inf
# 14                0.25     0.25         1.0   4.0    0.1875         inf
# 15                0.25     0.25         1.0   4.0    0.1875         inf
# 16                0.25     0.25         1.0   4.0    0.1875         inf
# 17                0.25     0.25         1.0   4.0    0.1875         inf
# 18                0.25     0.25         1.0   4.0    0.1875         inf
# 19                0.25     0.25         1.0   4.0    0.1875         inf
# 20                0.25     0.25         1.0   4.0    0.1875         inf
# 21                0.25     0.25         1.0   4.0    0.1875         inf
# 22                0.25     0.25         1.0   4.0    0.1875         inf
# 23                0.25     0.25         1.0   4.0    0.1875         inf
# 24                0.25     0.25         1.0   4.0    0.1875         inf
# 25                0.25     0.25         1.0   4.0    0.1875         inf
# 26                0.25     0.25         1.0   4.0    0.1875         inf
# 27                0.25     0.25         1.0   4.0    0.1875         inf
# 28                0.25     0.25         1.0   4.0    0.1875         inf
# 29                0.25     0.25         1.0   4.0    0.1875         inf
# 30                0.25     0.25         1.0   4.0    0.1875         inf
# 31                0.25     0.25         1.0   4.0    0.1875         inf
# 32                0.25     0.25         1.0   4.0    0.1875         inf
# 33                0.25     0.25         1.0   4.0    0.1875         inf
# 34                0.25     0.25         1.0   4.0    0.1875         inf
# 35                0.25     0.25         1.0   4.0    0.1875         inf
# 36                0.25     0.25         1.0   4.0    0.1875         inf
# 37                0.25     0.25         1.0   4.0    0.1875         inf
# 38                0.25     0.25         1.0   4.0    0.1875         inf
# 39                0.25     0.25         1.0   4.0    0.1875         inf
# 40                0.25     0.25         1.0   4.0    0.1875         inf
# 41                0.25     0.25         1.0   4.0    0.1875         inf
# 42                0.25     0.25         1.0   4.0    0.1875         inf
# 43                0.25     0.25         1.0   4.0    0.1875         inf
# 44                0.25     0.25         1.0   4.0    0.1875         inf
# 45                0.25     0.25         1.0   4.0    0.1875         inf
# 46                0.25     0.25         1.0   4.0    0.1875         inf
# 47                0.25     0.25         1.0   4.0    0.1875         inf
#
#     zhangs_metric
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.0
# 4             1.0
# 5             1.0
# 6             1.0
# 7             1.0
# 8             1.0
# 9             1.0
# 10            1.0
# 11            1.0
# 12            1.0
# 13            1.0
# 14            1.0
# 15            1.0
# 16            1.0
# 17            1.0
# 18            1.0
# 19            1.0
# 20            1.0
# 21            1.0
# 22            1.0
# 23            1.0
# 24            1.0
# 25            1.0
# 26            1.0
# 27            1.0
# 28            1.0
# 29            1.0
# 30            1.0
# 31            1.0
# 32            1.0
# 33            1.0
# 34            1.0
# 35            1.0
# 36            1.0
# 37            1.0
# 38            1.0
# 39            1.0
# 40            1.0
# 41            1.0
# 42            1.0
# 43            1.0
# 44            1.0
# 45            1.0
# 46            1.0
# 47            1.0

# %%
df8 = copy.deepcopy(df7)
df8
# Out:
#                  antecedents               consequents  antecedent support  \
# 0               (supplier_b)              (supplier_a)                0.25
# 1               (supplier_a)              (supplier_b)                0.25
# 2               (supplier_a)              (supplier_c)                0.25
# 3               (supplier_c)              (supplier_a)                0.25
# 4               (supplier_b)              (supplier_c)                0.25
# 5               (supplier_c)              (supplier_b)                0.25
# 6               (supplier_d)              (supplier_e)                0.25
# 7               (supplier_e)              (supplier_d)                0.25
# 8               (supplier_f)              (supplier_d)                0.25
# 9               (supplier_d)              (supplier_f)                0.25
# 10              (supplier_f)              (supplier_e)                0.25
# 11              (supplier_e)              (supplier_f)                0.25
# 12              (supplier_h)              (supplier_g)                0.25
# 13              (supplier_g)              (supplier_h)                0.25
# 14              (supplier_i)              (supplier_g)                0.25
# 15              (supplier_g)              (supplier_i)                0.25
# 16              (supplier_h)              (supplier_i)                0.25
# 17              (supplier_i)              (supplier_h)                0.25
# 18              (supplier_k)              (supplier_j)                0.25
# 19              (supplier_j)              (supplier_k)                0.25
# 20              (supplier_l)              (supplier_j)                0.25
# 21              (supplier_j)              (supplier_l)                0.25
# 22              (supplier_k)              (supplier_l)                0.25
# 23              (supplier_l)              (supplier_k)                0.25
# 24  (supplier_a, supplier_b)              (supplier_c)                0.25
# 25  (supplier_b, supplier_c)              (supplier_a)                0.25
# 26  (supplier_a, supplier_c)              (supplier_b)                0.25
# 27              (supplier_b)  (supplier_a, supplier_c)                0.25
# 28              (supplier_a)  (supplier_b, supplier_c)                0.25
# 29              (supplier_c)  (supplier_a, supplier_b)                0.25
# 30  (supplier_f, supplier_d)              (supplier_e)                0.25
# 31  (supplier_f, supplier_e)              (supplier_d)                0.25
# 32  (supplier_d, supplier_e)              (supplier_f)                0.25
# 33              (supplier_f)  (supplier_d, supplier_e)                0.25
# 34              (supplier_d)  (supplier_f, supplier_e)                0.25
# 35              (supplier_e)  (supplier_f, supplier_d)                0.25
# 36  (supplier_h, supplier_i)              (supplier_g)                0.25
# 37  (supplier_h, supplier_g)              (supplier_i)                0.25
# 38  (supplier_i, supplier_g)              (supplier_h)                0.25
# 39              (supplier_h)  (supplier_i, supplier_g)                0.25
# 40              (supplier_i)  (supplier_h, supplier_g)                0.25
# 41              (supplier_g)  (supplier_h, supplier_i)                0.25
# 42  (supplier_k, supplier_l)              (supplier_j)                0.25
# 43  (supplier_k, supplier_j)              (supplier_l)                0.25
# 44  (supplier_l, supplier_j)              (supplier_k)                0.25
# 45              (supplier_k)  (supplier_l, supplier_j)                0.25
# 46              (supplier_l)  (supplier_k, supplier_j)                0.25
# 47              (supplier_j)  (supplier_k, supplier_l)                0.25
#
#     consequent support  support  confidence  lift  leverage  conviction  \
# 0                 0.25     0.25         1.0   4.0    0.1875         inf
# 1                 0.25     0.25         1.0   4.0    0.1875         inf
# 2                 0.25     0.25         1.0   4.0    0.1875         inf
# 3                 0.25     0.25         1.0   4.0    0.1875         inf
# 4                 0.25     0.25         1.0   4.0    0.1875         inf
# 5                 0.25     0.25         1.0   4.0    0.1875         inf
# 6                 0.25     0.25         1.0   4.0    0.1875         inf
# 7                 0.25     0.25         1.0   4.0    0.1875         inf
# 8                 0.25     0.25         1.0   4.0    0.1875         inf
# 9                 0.25     0.25         1.0   4.0    0.1875         inf
# 10                0.25     0.25         1.0   4.0    0.1875         inf
# 11                0.25     0.25         1.0   4.0    0.1875         inf
# 12                0.25     0.25         1.0   4.0    0.1875         inf
# 13                0.25     0.25         1.0   4.0    0.1875         inf
# 14                0.25     0.25         1.0   4.0    0.1875         inf
# 15                0.25     0.25         1.0   4.0    0.1875         inf
# 16                0.25     0.25         1.0   4.0    0.1875         inf
# 17                0.25     0.25         1.0   4.0    0.1875         inf
# 18                0.25     0.25         1.0   4.0    0.1875         inf
# 19                0.25     0.25         1.0   4.0    0.1875         inf
# 20                0.25     0.25         1.0   4.0    0.1875         inf
# 21                0.25     0.25         1.0   4.0    0.1875         inf
# 22                0.25     0.25         1.0   4.0    0.1875         inf
# 23                0.25     0.25         1.0   4.0    0.1875         inf
# 24                0.25     0.25         1.0   4.0    0.1875         inf
# 25                0.25     0.25         1.0   4.0    0.1875         inf
# 26                0.25     0.25         1.0   4.0    0.1875         inf
# 27                0.25     0.25         1.0   4.0    0.1875         inf
# 28                0.25     0.25         1.0   4.0    0.1875         inf
# 29                0.25     0.25         1.0   4.0    0.1875         inf
# 30                0.25     0.25         1.0   4.0    0.1875         inf
# 31                0.25     0.25         1.0   4.0    0.1875         inf
# 32                0.25     0.25         1.0   4.0    0.1875         inf
# 33                0.25     0.25         1.0   4.0    0.1875         inf
# 34                0.25     0.25         1.0   4.0    0.1875         inf
# 35                0.25     0.25         1.0   4.0    0.1875         inf
# 36                0.25     0.25         1.0   4.0    0.1875         inf
# 37                0.25     0.25         1.0   4.0    0.1875         inf
# 38                0.25     0.25         1.0   4.0    0.1875         inf
# 39                0.25     0.25         1.0   4.0    0.1875         inf
# 40                0.25     0.25         1.0   4.0    0.1875         inf
# 41                0.25     0.25         1.0   4.0    0.1875         inf
# 42                0.25     0.25         1.0   4.0    0.1875         inf
# 43                0.25     0.25         1.0   4.0    0.1875         inf
# 44                0.25     0.25         1.0   4.0    0.1875         inf
# 45                0.25     0.25         1.0   4.0    0.1875         inf
# 46                0.25     0.25         1.0   4.0    0.1875         inf
# 47                0.25     0.25         1.0   4.0    0.1875         inf
#
#     zhangs_metric
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.0
# 4             1.0
# 5             1.0
# 6             1.0
# 7             1.0
# 8             1.0
# 9             1.0
# 10            1.0
# 11            1.0
# 12            1.0
# 13            1.0
# 14            1.0
# 15            1.0
# 16            1.0
# 17            1.0
# 18            1.0
# 19            1.0
# 20            1.0
# 21            1.0
# 22            1.0
# 23            1.0
# 24            1.0
# 25            1.0
# 26            1.0
# 27            1.0
# 28            1.0
# 29            1.0
# 30            1.0
# 31            1.0
# 32            1.0
# 33            1.0
# 34            1.0
# 35            1.0
# 36            1.0
# 37            1.0
# 38            1.0
# 39            1.0
# 40            1.0
# 41            1.0
# 42            1.0
# 43            1.0
# 44            1.0
# 45            1.0
# 46            1.0
# 47            1.0

# %%
df8['antecedents_values'] = df8['antecedents'].apply(lambda x: list(x)[0])
df8['consequents_values'] = df8['consequents'].apply(lambda x: list(x)[0])
df8
# Out:
#                  antecedents               consequents  antecedent support  \
# 0               (supplier_b)              (supplier_a)                0.25
# 1               (supplier_a)              (supplier_b)                0.25
# 2               (supplier_a)              (supplier_c)                0.25
# 3               (supplier_c)              (supplier_a)                0.25
# 4               (supplier_b)              (supplier_c)                0.25
# 5               (supplier_c)              (supplier_b)                0.25
# 6               (supplier_d)              (supplier_e)                0.25
# 7               (supplier_e)              (supplier_d)                0.25
# 8               (supplier_f)              (supplier_d)                0.25
# 9               (supplier_d)              (supplier_f)                0.25
# 10              (supplier_f)              (supplier_e)                0.25
# 11              (supplier_e)              (supplier_f)                0.25
# 12              (supplier_h)              (supplier_g)                0.25
# 13              (supplier_g)              (supplier_h)                0.25
# 14              (supplier_i)              (supplier_g)                0.25
# 15              (supplier_g)              (supplier_i)                0.25
# 16              (supplier_h)              (supplier_i)                0.25
# 17              (supplier_i)              (supplier_h)                0.25
# 18              (supplier_k)              (supplier_j)                0.25
# 19              (supplier_j)              (supplier_k)                0.25
# 20              (supplier_l)              (supplier_j)                0.25
# 21              (supplier_j)              (supplier_l)                0.25
# 22              (supplier_k)              (supplier_l)                0.25
# 23              (supplier_l)              (supplier_k)                0.25
# 24  (supplier_a, supplier_b)              (supplier_c)                0.25
# 25  (supplier_b, supplier_c)              (supplier_a)                0.25
# 26  (supplier_a, supplier_c)              (supplier_b)                0.25
# 27              (supplier_b)  (supplier_a, supplier_c)                0.25
# 28              (supplier_a)  (supplier_b, supplier_c)                0.25
# 29              (supplier_c)  (supplier_a, supplier_b)                0.25
# 30  (supplier_f, supplier_d)              (supplier_e)                0.25
# 31  (supplier_f, supplier_e)              (supplier_d)                0.25
# 32  (supplier_d, supplier_e)              (supplier_f)                0.25
# 33              (supplier_f)  (supplier_d, supplier_e)                0.25
# 34              (supplier_d)  (supplier_f, supplier_e)                0.25
# 35              (supplier_e)  (supplier_f, supplier_d)                0.25
# 36  (supplier_h, supplier_i)              (supplier_g)                0.25
# 37  (supplier_h, supplier_g)              (supplier_i)                0.25
# 38  (supplier_i, supplier_g)              (supplier_h)                0.25
# 39              (supplier_h)  (supplier_i, supplier_g)                0.25
# 40              (supplier_i)  (supplier_h, supplier_g)                0.25
# 41              (supplier_g)  (supplier_h, supplier_i)                0.25
# 42  (supplier_k, supplier_l)              (supplier_j)                0.25
# 43  (supplier_k, supplier_j)              (supplier_l)                0.25
# 44  (supplier_l, supplier_j)              (supplier_k)                0.25
# 45              (supplier_k)  (supplier_l, supplier_j)                0.25
# 46              (supplier_l)  (supplier_k, supplier_j)                0.25
# 47              (supplier_j)  (supplier_k, supplier_l)                0.25
#
#     consequent support  support  confidence  lift  leverage  conviction  \
# 0                 0.25     0.25         1.0   4.0    0.1875         inf
# 1                 0.25     0.25         1.0   4.0    0.1875         inf
# 2                 0.25     0.25         1.0   4.0    0.1875         inf
# 3                 0.25     0.25         1.0   4.0    0.1875         inf
# 4                 0.25     0.25         1.0   4.0    0.1875         inf
# 5                 0.25     0.25         1.0   4.0    0.1875         inf
# 6                 0.25     0.25         1.0   4.0    0.1875         inf
# 7                 0.25     0.25         1.0   4.0    0.1875         inf
# 8                 0.25     0.25         1.0   4.0    0.1875         inf
# 9                 0.25     0.25         1.0   4.0    0.1875         inf
# 10                0.25     0.25         1.0   4.0    0.1875         inf
# 11                0.25     0.25         1.0   4.0    0.1875         inf
# 12                0.25     0.25         1.0   4.0    0.1875         inf
# 13                0.25     0.25         1.0   4.0    0.1875         inf
# 14                0.25     0.25         1.0   4.0    0.1875         inf
# 15                0.25     0.25         1.0   4.0    0.1875         inf
# 16                0.25     0.25         1.0   4.0    0.1875         inf
# 17                0.25     0.25         1.0   4.0    0.1875         inf
# 18                0.25     0.25         1.0   4.0    0.1875         inf
# 19                0.25     0.25         1.0   4.0    0.1875         inf
# 20                0.25     0.25         1.0   4.0    0.1875         inf
# 21                0.25     0.25         1.0   4.0    0.1875         inf
# 22                0.25     0.25         1.0   4.0    0.1875         inf
# 23                0.25     0.25         1.0   4.0    0.1875         inf
# 24                0.25     0.25         1.0   4.0    0.1875         inf
# 25                0.25     0.25         1.0   4.0    0.1875         inf
# 26                0.25     0.25         1.0   4.0    0.1875         inf
# 27                0.25     0.25         1.0   4.0    0.1875         inf
# 28                0.25     0.25         1.0   4.0    0.1875         inf
# 29                0.25     0.25         1.0   4.0    0.1875         inf
# 30                0.25     0.25         1.0   4.0    0.1875         inf
# 31                0.25     0.25         1.0   4.0    0.1875         inf
# 32                0.25     0.25         1.0   4.0    0.1875         inf
# 33                0.25     0.25         1.0   4.0    0.1875         inf
# 34                0.25     0.25         1.0   4.0    0.1875         inf
# 35                0.25     0.25         1.0   4.0    0.1875         inf
# 36                0.25     0.25         1.0   4.0    0.1875         inf
# 37                0.25     0.25         1.0   4.0    0.1875         inf
# 38                0.25     0.25         1.0   4.0    0.1875         inf
# 39                0.25     0.25         1.0   4.0    0.1875         inf
# 40                0.25     0.25         1.0   4.0    0.1875         inf
# 41                0.25     0.25         1.0   4.0    0.1875         inf
# 42                0.25     0.25         1.0   4.0    0.1875         inf
# 43                0.25     0.25         1.0   4.0    0.1875         inf
# 44                0.25     0.25         1.0   4.0    0.1875         inf
# 45                0.25     0.25         1.0   4.0    0.1875         inf
# 46                0.25     0.25         1.0   4.0    0.1875         inf
# 47                0.25     0.25         1.0   4.0    0.1875         inf
#
#     zhangs_metric antecedents_values consequents_values
# 0             1.0         supplier_b         supplier_a
# 1             1.0         supplier_a         supplier_b
# 2             1.0         supplier_a         supplier_c
# 3             1.0         supplier_c         supplier_a
# 4             1.0         supplier_b         supplier_c
# 5             1.0         supplier_c         supplier_b
# 6             1.0         supplier_d         supplier_e
# 7             1.0         supplier_e         supplier_d
# 8             1.0         supplier_f         supplier_d
# 9             1.0         supplier_d         supplier_f
# 10            1.0         supplier_f         supplier_e
# 11            1.0         supplier_e         supplier_f
# 12            1.0         supplier_h         supplier_g
# 13            1.0         supplier_g         supplier_h
# 14            1.0         supplier_i         supplier_g
# 15            1.0         supplier_g         supplier_i
# 16            1.0         supplier_h         supplier_i
# 17            1.0         supplier_i         supplier_h
# 18            1.0         supplier_k         supplier_j
# 19            1.0         supplier_j         supplier_k
# 20            1.0         supplier_l         supplier_j
# 21            1.0         supplier_j         supplier_l
# 22            1.0         supplier_k         supplier_l
# 23            1.0         supplier_l         supplier_k
# 24            1.0         supplier_a         supplier_c
# 25            1.0         supplier_b         supplier_a
# 26            1.0         supplier_a         supplier_b
# 27            1.0         supplier_b         supplier_a
# 28            1.0         supplier_a         supplier_b
# 29            1.0         supplier_c         supplier_a
# 30            1.0         supplier_f         supplier_e
# 31            1.0         supplier_f         supplier_d
# 32            1.0         supplier_d         supplier_f
# 33            1.0         supplier_f         supplier_d
# 34            1.0         supplier_d         supplier_f
# 35            1.0         supplier_e         supplier_f
# 36            1.0         supplier_h         supplier_g
# 37            1.0         supplier_h         supplier_i
# 38            1.0         supplier_i         supplier_h
# 39            1.0         supplier_h         supplier_i
# 40            1.0         supplier_i         supplier_h
# 41            1.0         supplier_g         supplier_h
# 42            1.0         supplier_k         supplier_j
# 43            1.0         supplier_k         supplier_l
# 44            1.0         supplier_l         supplier_k
# 45            1.0         supplier_k         supplier_l
# 46            1.0         supplier_l         supplier_k
# 47            1.0         supplier_j         supplier_k

# %%
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48 entries, 0 to 47
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   antecedents         48 non-null     object
#  1   consequents         48 non-null     object
#  2   antecedent support  48 non-null     float64
#  3   consequent support  48 non-null     float64
#  4   support             48 non-null     float64
#  5   confidence          48 non-null     float64
#  6   lift                48 non-null     float64
#  7   leverage            48 non-null     float64
#  8   conviction          48 non-null     float64
#  9   zhangs_metric       48 non-null     float64
#  10  antecedents_values  48 non-null     object
#  11  consequents_values  48 non-null     object
# dtypes: float64(8), object(4)
# memory usage: 4.9+ KB

# %%
df8['redundant'] = df8[['antecedents_values','consequents_values']].values.tolist()
df8['redundant'] = df8['redundant'].apply(sorted)
df8['redundant'] = df8['redundant'].apply(lambda x: ', '.join(x))
df8
# Out:
#                  antecedents               consequents  antecedent support  \
# 0               (supplier_b)              (supplier_a)                0.25
# 1               (supplier_a)              (supplier_b)                0.25
# 2               (supplier_a)              (supplier_c)                0.25
# 3               (supplier_c)              (supplier_a)                0.25
# 4               (supplier_b)              (supplier_c)                0.25
# 5               (supplier_c)              (supplier_b)                0.25
# 6               (supplier_d)              (supplier_e)                0.25
# 7               (supplier_e)              (supplier_d)                0.25
# 8               (supplier_f)              (supplier_d)                0.25
# 9               (supplier_d)              (supplier_f)                0.25
# 10              (supplier_f)              (supplier_e)                0.25
# 11              (supplier_e)              (supplier_f)                0.25
# 12              (supplier_h)              (supplier_g)                0.25
# 13              (supplier_g)              (supplier_h)                0.25
# 14              (supplier_i)              (supplier_g)                0.25
# 15              (supplier_g)              (supplier_i)                0.25
# 16              (supplier_h)              (supplier_i)                0.25
# 17              (supplier_i)              (supplier_h)                0.25
# 18              (supplier_k)              (supplier_j)                0.25
# 19              (supplier_j)              (supplier_k)                0.25
# 20              (supplier_l)              (supplier_j)                0.25
# 21              (supplier_j)              (supplier_l)                0.25
# 22              (supplier_k)              (supplier_l)                0.25
# 23              (supplier_l)              (supplier_k)                0.25
# 24  (supplier_a, supplier_b)              (supplier_c)                0.25
# 25  (supplier_b, supplier_c)              (supplier_a)                0.25
# 26  (supplier_a, supplier_c)              (supplier_b)                0.25
# 27              (supplier_b)  (supplier_a, supplier_c)                0.25
# 28              (supplier_a)  (supplier_b, supplier_c)                0.25
# 29              (supplier_c)  (supplier_a, supplier_b)                0.25
# 30  (supplier_f, supplier_d)              (supplier_e)                0.25
# 31  (supplier_f, supplier_e)              (supplier_d)                0.25
# 32  (supplier_d, supplier_e)              (supplier_f)                0.25
# 33              (supplier_f)  (supplier_d, supplier_e)                0.25
# 34              (supplier_d)  (supplier_f, supplier_e)                0.25
# 35              (supplier_e)  (supplier_f, supplier_d)                0.25
# 36  (supplier_h, supplier_i)              (supplier_g)                0.25
# 37  (supplier_h, supplier_g)              (supplier_i)                0.25
# 38  (supplier_i, supplier_g)              (supplier_h)                0.25
# 39              (supplier_h)  (supplier_i, supplier_g)                0.25
# 40              (supplier_i)  (supplier_h, supplier_g)                0.25
# 41              (supplier_g)  (supplier_h, supplier_i)                0.25
# 42  (supplier_k, supplier_l)              (supplier_j)                0.25
# 43  (supplier_k, supplier_j)              (supplier_l)                0.25
# 44  (supplier_l, supplier_j)              (supplier_k)                0.25
# 45              (supplier_k)  (supplier_l, supplier_j)                0.25
# 46              (supplier_l)  (supplier_k, supplier_j)                0.25
# 47              (supplier_j)  (supplier_k, supplier_l)                0.25
#
#     consequent support  support  confidence  lift  leverage  conviction  \
# 0                 0.25     0.25         1.0   4.0    0.1875         inf
# 1                 0.25     0.25         1.0   4.0    0.1875         inf
# 2                 0.25     0.25         1.0   4.0    0.1875         inf
# 3                 0.25     0.25         1.0   4.0    0.1875         inf
# 4                 0.25     0.25         1.0   4.0    0.1875         inf
# 5                 0.25     0.25         1.0   4.0    0.1875         inf
# 6                 0.25     0.25         1.0   4.0    0.1875         inf
# 7                 0.25     0.25         1.0   4.0    0.1875         inf
# 8                 0.25     0.25         1.0   4.0    0.1875         inf
# 9                 0.25     0.25         1.0   4.0    0.1875         inf
# 10                0.25     0.25         1.0   4.0    0.1875         inf
# 11                0.25     0.25         1.0   4.0    0.1875         inf
# 12                0.25     0.25         1.0   4.0    0.1875         inf
# 13                0.25     0.25         1.0   4.0    0.1875         inf
# 14                0.25     0.25         1.0   4.0    0.1875         inf
# 15                0.25     0.25         1.0   4.0    0.1875         inf
# 16                0.25     0.25         1.0   4.0    0.1875         inf
# 17                0.25     0.25         1.0   4.0    0.1875         inf
# 18                0.25     0.25         1.0   4.0    0.1875         inf
# 19                0.25     0.25         1.0   4.0    0.1875         inf
# 20                0.25     0.25         1.0   4.0    0.1875         inf
# 21                0.25     0.25         1.0   4.0    0.1875         inf
# 22                0.25     0.25         1.0   4.0    0.1875         inf
# 23                0.25     0.25         1.0   4.0    0.1875         inf
# 24                0.25     0.25         1.0   4.0    0.1875         inf
# 25                0.25     0.25         1.0   4.0    0.1875         inf
# 26                0.25     0.25         1.0   4.0    0.1875         inf
# 27                0.25     0.25         1.0   4.0    0.1875         inf
# 28                0.25     0.25         1.0   4.0    0.1875         inf
# 29                0.25     0.25         1.0   4.0    0.1875         inf
# 30                0.25     0.25         1.0   4.0    0.1875         inf
# 31                0.25     0.25         1.0   4.0    0.1875         inf
# 32                0.25     0.25         1.0   4.0    0.1875         inf
# 33                0.25     0.25         1.0   4.0    0.1875         inf
# 34                0.25     0.25         1.0   4.0    0.1875         inf
# 35                0.25     0.25         1.0   4.0    0.1875         inf
# 36                0.25     0.25         1.0   4.0    0.1875         inf
# 37                0.25     0.25         1.0   4.0    0.1875         inf
# 38                0.25     0.25         1.0   4.0    0.1875         inf
# 39                0.25     0.25         1.0   4.0    0.1875         inf
# 40                0.25     0.25         1.0   4.0    0.1875         inf
# 41                0.25     0.25         1.0   4.0    0.1875         inf
# 42                0.25     0.25         1.0   4.0    0.1875         inf
# 43                0.25     0.25         1.0   4.0    0.1875         inf
# 44                0.25     0.25         1.0   4.0    0.1875         inf
# 45                0.25     0.25         1.0   4.0    0.1875         inf
# 46                0.25     0.25         1.0   4.0    0.1875         inf
# 47                0.25     0.25         1.0   4.0    0.1875         inf
#
#     zhangs_metric antecedents_values consequents_values  \
# 0             1.0         supplier_b         supplier_a
# 1             1.0         supplier_a         supplier_b
# 2             1.0         supplier_a         supplier_c
# 3             1.0         supplier_c         supplier_a
# 4             1.0         supplier_b         supplier_c
# 5             1.0         supplier_c         supplier_b
# 6             1.0         supplier_d         supplier_e
# 7             1.0         supplier_e         supplier_d
# 8             1.0         supplier_f         supplier_d
# 9             1.0         supplier_d         supplier_f
# 10            1.0         supplier_f         supplier_e
# 11            1.0         supplier_e         supplier_f
# 12            1.0         supplier_h         supplier_g
# 13            1.0         supplier_g         supplier_h
# 14            1.0         supplier_i         supplier_g
# 15            1.0         supplier_g         supplier_i
# 16            1.0         supplier_h         supplier_i
# 17            1.0         supplier_i         supplier_h
# 18            1.0         supplier_k         supplier_j
# 19            1.0         supplier_j         supplier_k
# 20            1.0         supplier_l         supplier_j
# 21            1.0         supplier_j         supplier_l
# 22            1.0         supplier_k         supplier_l
# 23            1.0         supplier_l         supplier_k
# 24            1.0         supplier_a         supplier_c
# 25            1.0         supplier_b         supplier_a
# 26            1.0         supplier_a         supplier_b
# 27            1.0         supplier_b         supplier_a
# 28            1.0         supplier_a         supplier_b
# 29            1.0         supplier_c         supplier_a
# 30            1.0         supplier_f         supplier_e
# 31            1.0         supplier_f         supplier_d
# 32            1.0         supplier_d         supplier_f
# 33            1.0         supplier_f         supplier_d
# 34            1.0         supplier_d         supplier_f
# 35            1.0         supplier_e         supplier_f
# 36            1.0         supplier_h         supplier_g
# 37            1.0         supplier_h         supplier_i
# 38            1.0         supplier_i         supplier_h
# 39            1.0         supplier_h         supplier_i
# 40            1.0         supplier_i         supplier_h
# 41            1.0         supplier_g         supplier_h
# 42            1.0         supplier_k         supplier_j
# 43            1.0         supplier_k         supplier_l
# 44            1.0         supplier_l         supplier_k
# 45            1.0         supplier_k         supplier_l
# 46            1.0         supplier_l         supplier_k
# 47            1.0         supplier_j         supplier_k
#
#                  redundant
# 0   supplier_a, supplier_b
# 1   supplier_a, supplier_b
# 2   supplier_a, supplier_c
# 3   supplier_a, supplier_c
# 4   supplier_b, supplier_c
# 5   supplier_b, supplier_c
# 6   supplier_d, supplier_e
# 7   supplier_d, supplier_e
# 8   supplier_d, supplier_f
# 9   supplier_d, supplier_f
# 10  supplier_e, supplier_f
# 11  supplier_e, supplier_f
# 12  supplier_g, supplier_h
# 13  supplier_g, supplier_h
# 14  supplier_g, supplier_i
# 15  supplier_g, supplier_i
# 16  supplier_h, supplier_i
# 17  supplier_h, supplier_i
# 18  supplier_j, supplier_k
# 19  supplier_j, supplier_k
# 20  supplier_j, supplier_l
# 21  supplier_j, supplier_l
# 22  supplier_k, supplier_l
# 23  supplier_k, supplier_l
# 24  supplier_a, supplier_c
# 25  supplier_a, supplier_b
# 26  supplier_a, supplier_b
# 27  supplier_a, supplier_b
# 28  supplier_a, supplier_b
# 29  supplier_a, supplier_c
# 30  supplier_e, supplier_f
# 31  supplier_d, supplier_f
# 32  supplier_d, supplier_f
# 33  supplier_d, supplier_f
# 34  supplier_d, supplier_f
# 35  supplier_e, supplier_f
# 36  supplier_g, supplier_h
# 37  supplier_h, supplier_i
# 38  supplier_h, supplier_i
# 39  supplier_h, supplier_i
# 40  supplier_h, supplier_i
# 41  supplier_g, supplier_h
# 42  supplier_j, supplier_k
# 43  supplier_k, supplier_l
# 44  supplier_k, supplier_l
# 45  supplier_k, supplier_l
# 46  supplier_k, supplier_l
# 47  supplier_j, supplier_k

# %%
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48 entries, 0 to 47
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   antecedents         48 non-null     object
#  1   consequents         48 non-null     object
#  2   antecedent support  48 non-null     float64
#  3   consequent support  48 non-null     float64
#  4   support             48 non-null     float64
#  5   confidence          48 non-null     float64
#  6   lift                48 non-null     float64
#  7   leverage            48 non-null     float64
#  8   conviction          48 non-null     float64
#  9   zhangs_metric       48 non-null     float64
#  10  antecedents_values  48 non-null     object
#  11  consequents_values  48 non-null     object
#  12  redundant           48 non-null     object
# dtypes: float64(8), object(5)
# memory usage: 5.2+ KB

# %%
df8 = df8.drop_duplicates(subset=['support','confidence','lift','redundant'], ignore_index=True)
df8
# Out:
#      antecedents   consequents  antecedent support  consequent support  \
# 0   (supplier_b)  (supplier_a)                0.25                0.25
# 1   (supplier_a)  (supplier_c)                0.25                0.25
# 2   (supplier_b)  (supplier_c)                0.25                0.25
# 3   (supplier_d)  (supplier_e)                0.25                0.25
# 4   (supplier_f)  (supplier_d)                0.25                0.25
# 5   (supplier_f)  (supplier_e)                0.25                0.25
# 6   (supplier_h)  (supplier_g)                0.25                0.25
# 7   (supplier_i)  (supplier_g)                0.25                0.25
# 8   (supplier_h)  (supplier_i)                0.25                0.25
# 9   (supplier_k)  (supplier_j)                0.25                0.25
# 10  (supplier_l)  (supplier_j)                0.25                0.25
# 11  (supplier_k)  (supplier_l)                0.25                0.25
#
#     support  confidence  lift  leverage  conviction  zhangs_metric  \
# 0      0.25         1.0   4.0    0.1875         inf            1.0
# 1      0.25         1.0   4.0    0.1875         inf            1.0
# 2      0.25         1.0   4.0    0.1875         inf            1.0
# 3      0.25         1.0   4.0    0.1875         inf            1.0
# 4      0.25         1.0   4.0    0.1875         inf            1.0
# 5      0.25         1.0   4.0    0.1875         inf            1.0
# 6      0.25         1.0   4.0    0.1875         inf            1.0
# 7      0.25         1.0   4.0    0.1875         inf            1.0
# 8      0.25         1.0   4.0    0.1875         inf            1.0
# 9      0.25         1.0   4.0    0.1875         inf            1.0
# 10     0.25         1.0   4.0    0.1875         inf            1.0
# 11     0.25         1.0   4.0    0.1875         inf            1.0
#
#    antecedents_values consequents_values               redundant
# 0          supplier_b         supplier_a  supplier_a, supplier_b
# 1          supplier_a         supplier_c  supplier_a, supplier_c
# 2          supplier_b         supplier_c  supplier_b, supplier_c
# 3          supplier_d         supplier_e  supplier_d, supplier_e
# 4          supplier_f         supplier_d  supplier_d, supplier_f
# 5          supplier_f         supplier_e  supplier_e, supplier_f
# 6          supplier_h         supplier_g  supplier_g, supplier_h
# 7          supplier_i         supplier_g  supplier_g, supplier_i
# 8          supplier_h         supplier_i  supplier_h, supplier_i
# 9          supplier_k         supplier_j  supplier_j, supplier_k
# 10         supplier_l         supplier_j  supplier_j, supplier_l
# 11         supplier_k         supplier_l  supplier_k, supplier_l
